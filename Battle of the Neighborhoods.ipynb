# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd 
import numpy as np 
import random 
import requests
# !pip install geopy
from geopy.geocoders import Nominatim 
from pandas.io.json import json_normalize
! pip install folium==0.5.0
import folium 

print('Folium installed')
print('Libraries imported.')
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: folium==0.5.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.3)
# Requirement already satisfied: branca in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials to access Foursquare location data

# %%
# CLIENT_ID = ' ' 
# CLIENT_SECRET = ' ' 
# ACCESS_TOKEN = '' 
# VERSION = ' '
# LIMIT = 50

print('Your credentials: CLIENT_ID, CLIENT_SECRET have been installed')
# Out:
# Your credentials: CLIENT_ID, CLIENT_SECRET have been installed

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ### Define a user-agent to access geocoder for Four Seasons Seattle.

# %%
address = '99 Union St, Seattle, WA 98101'

geolocator = Nominatim(user_agent="seattle_foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 47.607375700000006 -122.3391602000244

# %% [markdown]
# ### Define a search query for bakeries in Seattle, Washington.

# %%
search_query = 'Bakery'
radius = 1500
print(search_query + ' in Seattle .... OK!')
# Out:
# Bakery in Seattle .... OK!

# %% [markdown]
# ### Define Foursquare API URL

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#  Foursquare API URL installed...

# %% [markdown]
# ### Send a GET Request to examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60cffbf0a50fc23e5ab91a12'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '47f245d1f964a520974e1fe3',
#     'name': 'Three Girls Bakery',
#     'location': {'address': '1514 Pike Pl',
#      'crossStreet': 'in Post Alley',
#      'lat': 47.60906474579556,
#      'lng': -122.34091319298555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60906474579556,
#        'lng': -122.34091319298555},
#       {'label': 'entrance', 'lat': 47.609094, 'lng': -122.340702}],
#      'distance': 229,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['1514 Pike Pl (in Post Alley)',
#       'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1910007',
#      'url': 'https://www.grubhub.com/restaurant/three-girls-bakery-1514-pike-place-seattle/1910007?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1910007',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4b9d10c1f964a5208f8c36e3',
#     'name': 'Pike Place Bakery',
#     'location': {'address': '1501 Pike Pl',
#      'crossStreet': 'at Pike Place Market',
#      'lat': 47.60883450562949,
#      'lng': -122.34049849125356,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60883450562949,
#        'lng': -122.34049849125356},
#       {'label': 'entrance', 'lat': 47.608768, 'lng': -122.340912}],
#      'distance': 190,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['1501 Pike Pl (at Pike Place Market)',
#       'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4c77edff93ef236afa74aa0f',
#     'name': 'Alaskan Sourdough Bakery',
#     'location': {'address': '1301 Alaskan Way',
#      'lat': 47.60616201806928,
#      'lng': -122.34125559886061,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60616201806928,
#        'lng': -122.34125559886061}],
#      'distance': 207,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['1301 Alaskan Way', 'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '559475',
#      'url': 'https://www.grubhub.com/restaurant/alaskan-sourdough-bakery-1301-alaskan-way-seattle/559475?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=559475',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '427ff980f964a520d8211fe3',
#     'name': 'Macrina Bakery',
#     'location': {'address': '2408 1st Ave',
#      'crossStreet': 'btwn Wall & Battery',
#      'lat': 47.61440633728934,
#      'lng': -122.34815542094019,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.61440633728934,
#        'lng': -122.34815542094019},
#       {'label': 'entrance', 'lat': 47.614391, 'lng': -122.347946}],
#      'distance': 1033,
#      'postalCode': '98121',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['2408 1st Ave (btwn Wall & Battery)',
#       'Seattle, WA 98121']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '49fa01c1f964a520a56d1fe3',
#     'name': 'Dahlia Bakery',
#     'location': {'address': '2001 4th Ave',
#      'crossStreet': 'at Virginia St',
#      'lat': 47.613162,
#      'lng': -122.340606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.613162,
#        'lng': -122.340606}],
#      'distance': 653,
#      'postalCode': '98121',
#      'cc': 'US',
#      'neighborhood': 'Belltown',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['2001 4th Ave (at Virginia St)',
#       'Seattle, WA 98121']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4aae9e5cf964a520a36220e3',
#     'name': 'Sugar Bakery + Cafe',
#     'location': {'address': '1014 Madison St',
#      'crossStreet': 'btwn Terry & Boren',
#      'lat': 47.60914869775373,
#      'lng': -122.32578981414184,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60914869775373,
#        'lng': -122.32578981414184},
#       {'label': 'entrance', 'lat': 47.609147, 'lng': -122.325854}],
#      'distance': 1022,
#      'postalCode': '98104',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['1014 Madison St (btwn Terry & Boren)',
#       'Seattle, WA 98104']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '418928',
#      'url': 'https://www.grubhub.com/restaurant/sugar-bakery--cafe-1014-madison-street-seattle/418928?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=418928',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4ca7b9f4f47ea143a9d46d21',
#     'name': 'Fuji Bakery',
#     'location': {'address': '526 S King St',
#      'lat': 47.59835648956966,
#      'lng': -122.32641879822985,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.59835648956966,
#        'lng': -122.32641879822985},
#       {'label': 'entrance', 'lat': 47.598447, 'lng': -122.326574}],
#      'distance': 1386,
#      'postalCode': '98104',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['526 S King St', 'Seattle, WA 98104']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4dc0684e5da386e218c760a1',
#     'name': 'Il Fornaio Bakery & Café',
#     'location': {'address': '600 Pine St',
#      'crossStreet': 'at Pacific Place',
#      'lat': 47.61263549811077,
#      'lng': -122.33493854320552,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.61263549811077,
#        'lng': -122.33493854320552},
#       {'label': 'entrance', 'lat': 47.613293, 'lng': -122.335652}],
#      'distance': 665,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['600 Pine St (at Pacific Place)',
#       'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4a95c280f964a5208a2420e3',
#     'name': 'Specialty’s Café & Bakery',
#     'location': {'address': '701 5th Avenue',
#      'crossStreet': '4th & Columbia (in Columbia Center)',
#      'lat': 47.60466704,
#      'lng': -122.33051677,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60466704,
#        'lng': -122.33051677}],
#      'distance': 715,
#      'postalCode': '98104',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['701 5th Avenue (4th & Columbia (in Columbia Center))',
#       'Seattle, WA 98104']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '553301538'},
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '500c453de4b053e6581c8227',
#     'name': 'Seattle Bagel Bakery',
#     'location': {'lat': 47.60881358596356,
#      'lng': -122.34030305795996,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60881358596356,
#        'lng': -122.34030305795996}],
#      'distance': 181,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d179941735',
#       'name': 'Bagel Shop',
#       'pluralName': 'Bagel Shops',
#       'shortName': 'Bagels',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4a70b83ef964a52043d81fe3',
#     'name': 'Grand Central Bakery',
#     'location': {'address': '214 1st Ave S',
#      'crossStreet': 'btw Washington & Main',
#      'lat': 47.6003390934002,
#      'lng': -122.33335862800976,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.6003390934002,
#        'lng': -122.33335862800976}],
#      'distance': 896,
#      'postalCode': '98104',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['214 1st Ave S (btw Washington & Main)',
#       'Seattle, WA 98104']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4b118149f964a520077e23e3',
#     'name': 'Sun Bakery & Deli',
#     'location': {'address': '658 S Jackson St',
#      'crossStreet': 'Maynard Ave',
#      'lat': 47.599459,
#      'lng': -122.32468600000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.599459,
#        'lng': -122.32468600000001},
#       {'label': 'entrance', 'lat': 47.599311, 'lng': -122.324582}],
#      'distance': 1398,
#      'postalCode': '98104',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['658 S Jackson St (Maynard Ave)',
#       'Seattle, WA 98104']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '5c8bc600cd441c002c256991',
#     'name': 'The Barque Brontes Bakery Café',
#     'location': {'address': '1426 Western Ave',
#      'lat': 47.60818,
#      'lng': -122.340625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60818,
#        'lng': -122.340625}],
#      'distance': 141,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['1426 Western Ave', 'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '49e54ff8f964a520b7631fe3',
#     'name': 'Three Dog Bakery',
#     'location': {'address': '1418 1st Ave',
#      'crossStreet': 'Pike',
#      'lat': 47.608543395996094,
#      'lng': -122.33929443359375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.608543395996094,
#        'lng': -122.33929443359375}],
#      'distance': 130,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['1418 1st Ave (Pike)', 'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d100951735',
#       'name': 'Pet Store',
#       'pluralName': 'Pet Stores',
#       'shortName': 'Pet Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4d8285514bbaa09302c4c3ac',
#     'name': 'Bakery',
#     'location': {'address': '123 Bell St',
#      'crossStreet': '2nd ave',
#      'lat': 47.613792,
#      'lng': -122.34563200000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.613792,
#        'lng': -122.34563200000001}],
#      'distance': 863,
#      'postalCode': '98121',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['123 Bell St (2nd ave)', 'Seattle, WA 98121']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4c30dc5a452620a18ec11f0f',
#     'name': "Little Rae's Bakery",
#     'location': {'address': 'Pike Place',
#      'crossStreet': 'Stewart Street',
#      'lat': 47.609703540802,
#      'lng': -122.34200656414032,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.609703540802,
#        'lng': -122.34200656414032}],
#      'distance': 335,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['Pike Place (Stewart Street)', 'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '5da9e7152e1828000755cb58',
#     'name': 'Very French Bakery',
#     'location': {'lat': 47.609761,
#      'lng': -122.342302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.609761,
#        'lng': -122.342302}],
#      'distance': 355,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '527af60211d2ec38661701d3',
#     'name': "M's Bakery Piper",
#     'location': {'lat': 47.60702022170549,
#      'lng': -122.33353614807129,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60702022170549,
#        'lng': -122.33353614807129}],
#      'distance': 423,
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['Seattle, WA']},
#     'categories': [{'id': '4bf58dd8d48988d10d951735',
#       'name': 'Record Shop',
#       'pluralName': 'Record Shops',
#       'shortName': 'Record Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/record_shop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '5fa31df322431d18f152573c',
#     'name': 'Askatu Bakery Cafe',
#     'location': {'address': '2209 4th Ave',
#      'lat': 47.61474142267071,
#      'lng': -122.34314611989248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.61474142267071,
#        'lng': -122.34314611989248}],
#      'distance': 872,
#      'postalCode': '98121',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['2209 4th Ave', 'Seattle, WA 98121']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4f32abf619836c91c7ee75ee',
#     'name': 'Bullseye Bakery',
#     'location': {'address': '999 3rd Ave',
#      'lat': 47.604909,
#      'lng': -122.333368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.604909,
#        'lng': -122.333368}],
#      'distance': 514,
#      'postalCode': '98104',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['999 3rd Ave', 'Seattle, WA 98104']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '503fca64e4b01555a556c1dc',
#     'name': 'post deli & bakery',
#     'location': {'address': '90 Yesler Way',
#      'crossStreet': 'Post Ave',
#      'lat': 47.60187911987305,
#      'lng': -122.33474731445312,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60187911987305,
#        'lng': -122.33474731445312}],
#      'distance': 695,
#      'postalCode': '98104',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['90 Yesler Way (Post Ave)', 'Seattle, WA 98104']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4b0088dff964a5203a3f22e3',
#     'name': 'Yummy House Bakery',
#     'location': {'address': '522 6th Ave S',
#      'lat': 47.597742569769764,
#      'lng': -122.32629806182162,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.597742569769764,
#        'lng': -122.32629806182162},
#       {'label': 'entrance', 'lat': 47.597718, 'lng': -122.326226}],
#      'distance': 1442,
#      'postalCode': '98104',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['522 6th Ave S', 'Seattle, WA 98104']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1755426',
#      'url': 'https://www.grubhub.com/restaurant/chinese-yum-yum-663-s-weller-st-seattle/1755426?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1755426',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '60c66ddcd8fcb45d94bc8991',
#     'name': 'Little Prague Bakery',
#     'location': {'lat': 47.61881,
#      'lng': -122.32006,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.61881,
#        'lng': -122.32006}],
#      'distance': 1916,
#      'postalCode': '98122',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['Seattle, WA 98122']},
#     'categories': [{'id': '4bf58dd8d48988d1fa941735',
#       'name': 'Farmers Market',
#       'pluralName': 'Farmers Markets',
#       'shortName': "Farmer's Market",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '5c250ed5f05ca8002d315e9d',
#     'name': '85C Bakery Cafe',
#     'location': {'address': '501 S Jackson St',
#      'lat': 47.59912343124828,
#      'lng': -122.32777929828116,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.59912343124828,
#        'lng': -122.32777929828116}],
#      'distance': 1254,
#      'postalCode': '98104',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['501 S Jackson St', 'Seattle, WA 98104']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4db5d64df7b121c29f66e56c',
#     'name': 'Wild Rye Cafe Bakery',
#     'location': {'address': '806 Pike St',
#      'crossStreet': 'at The Conference Center',
#      'lat': 47.61220836262033,
#      'lng': -122.3321179385548,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.61220836262033,
#        'lng': -122.3321179385548},
#       {'label': 'entrance', 'lat': 47.612459, 'lng': -122.331653}],
#      'distance': 754,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['806 Pike St (at The Conference Center)',
#       'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4a5bc4d8f964a520bebb1fe3',
#     'name': 'Uptown Espresso & Bakery',
#     'location': {'address': '2801 Alaskan Way',
#      'lat': 47.614984976810454,
#      'lng': -122.35473026187154,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.614984976810454,
#        'lng': -122.35473026187154}],
#      'distance': 1443,
#      'postalCode': '98121',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['2801 Alaskan Way', 'Seattle, WA 98121']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1912324',
#      'url': 'https://www.grubhub.com/restaurant/uptown-espresso--bakery-2801-alaskan-way-seattle/1912324?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1912324',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4fd202d2e4b0c160c2da1acf',
#     'name': 'Opaline Cafe & Bakery',
#     'location': {'address': '2229 5th Ave',
#      'lat': 47.61668650060831,
#      'lng': -122.34518575902686,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.61668650060831,
#        'lng': -122.34518575902686}],
#      'distance': 1130,
#      'postalCode': '98121',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['2229 5th Ave', 'Seattle, WA 98121']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '5e4865298f54b10008acc646',
#     'name': 'Holy Bee’s Bakery',
#     'location': {'lat': 47.614863,
#      'lng': -122.349182,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.614863,
#        'lng': -122.349182}],
#      'distance': 1122,
#      'postalCode': '98121',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['Seattle, WA 98121']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2028252',
#      'url': 'https://www.grubhub.com/restaurant/holy-bees-bakery-2521-1st-ave-ste-110-seattle/2028252?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2028252',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '419e8900f964a520301e1fe3',
#     'name': 'Le Panier',
#     'location': {'address': '1902 Pike Pl',
#      'crossStreet': 'at Stewart St',
#      'lat': 47.6097907988089,
#      'lng': -122.34225747070934,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.6097907988089,
#        'lng': -122.34225747070934},
#       {'label': 'entrance', 'lat': 47.609833, 'lng': -122.342298}],
#      'distance': 355,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['1902 Pike Pl (at Stewart St)',
#       'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '5a930c035315930874d4da4e',
#     'name': 'Seattle Bagel Bakery',
#     'location': {'address': '2719 1st Ave',
#      'lat': 47.616002,
#      'lng': -122.35148899999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.616002,
#        'lng': -122.35148899999999},
#       {'label': 'entrance', 'lat': 47.616143, 'lng': -122.351393}],
#      'distance': 1333,
#      'postalCode': '98121',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['2719 1st Ave', 'Seattle, WA 98121']},
#     'categories': [{'id': '4bf58dd8d48988d179941735',
#       'name': 'Bagel Shop',
#       'pluralName': 'Bagel Shops',
#       'shortName': 'Bagels',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '56b5014f498e18dc051f2ba7',
#     'name': 'Standard Bakery',
#     'location': {'address': '400 Fairview Ave. N',
#      'lat': 47.62254333496094,
#      'lng': -122.33391571044922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.62254333496094,
#        'lng': -122.33391571044922}],
#      'distance': 1733,
#      'postalCode': '98109',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['400 Fairview Ave. N', 'Seattle, WA 98109']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '423f6000f964a5205a201fe3',
#     'name': 'Uptown Espresso',
#     'location': {'address': '2504 4th Ave',
#      'crossStreet': 'at Wall St',
#      'lat': 47.61690089103363,
#      'lng': -122.34636367197227,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.61690089103363,
#        'lng': -122.34636367197227},
#       {'label': 'entrance', 'lat': 47.616909, 'lng': -122.346284}],
#      'distance': 1190,
#      'postalCode': '98121',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['2504 4th Ave (at Wall St)', 'Seattle, WA 98121']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1906741',
#      'url': 'https://www.grubhub.com/restaurant/uptown-espresso-belltown-2504-4th-avenue-seattle/1906741?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1906741',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4bd608e86f649521662c70ec',
#     'name': 'Le Chatel',
#     'location': {'address': '1301 5th Ave',
#      'crossStreet': 'at University',
#      'lat': 47.60913723217863,
#      'lng': -122.33419449487764,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60913723217863,
#        'lng': -122.33419449487764}],
#      'distance': 421,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['1301 5th Ave (at University)',
#       'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '47bd7b34f964a520d94d1fe3',
#     'name': 'Sisters European Snacks',
#     'location': {'address': '1530 Post Aly',
#      'crossStreet': 'at Pine St',
#      'lat': 47.60941371869453,
#      'lng': -122.34131118894764,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.60941371869453,
#        'lng': -122.34131118894764},
#       {'label': 'entrance', 'lat': 47.609084, 'lng': -122.340978}],
#      'distance': 278,
#      'postalCode': '98101',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['1530 Post Aly (at Pine St)', 'Seattle, WA 98101']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2332540',
#      'url': 'https://www.grubhub.com/restaurant/sisters-european-cafe-1530-post-alley-seattle/2332540?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2332540',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '208298565'},
#     'referralId': 'v-1624243185',
#     'hasPerk': False},
#    {'id': '4bead6499fa3ef3b932e80c9',
#     'name': 'Panera Bread',
#     'location': {'address': '1620 Broadway Ste 100A',
#      'lat': 47.616242,
#      'lng': -122.320553,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 47.616242,
#        'lng': -122.320553},
#       {'label': 'entrance', 'lat': 47.615943, 'lng': -122.320641}],
#      'distance': 1709,
#      'postalCode': '98122',
#      'cc': 'US',
#      'city': 'Seattle',
#      'state': 'WA',
#      'country': 'United States',
#      'formattedAddress': ['1620 Broadway Ste 100A', 'Seattle, WA 98122']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243185',
#     'hasPerk': False}]}}

# %% [markdown]
# ### Specify a JSON search to bakeries and transforming data into a pandas dataframe

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
#                          id                      name  \
# 0  47f245d1f964a520974e1fe3        Three Girls Bakery
# 1  4b9d10c1f964a5208f8c36e3         Pike Place Bakery
# 2  4c77edff93ef236afa74aa0f  Alaskan Sourdough Bakery
# 3  427ff980f964a520d8211fe3            Macrina Bakery
# 4  49fa01c1f964a520a56d1fe3             Dahlia Bakery
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1624243185    False
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1624243185    False
# 2  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1624243185    False
# 3  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1624243185    False
# 4  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1624243185    False
#
#    location.address  location.crossStreet  location.lat  location.lng  \
# 0      1514 Pike Pl         in Post Alley     47.609065   -122.340913
# 1      1501 Pike Pl  at Pike Place Market     47.608835   -122.340498
# 2  1301 Alaskan Way                   NaN     47.606162   -122.341256
# 3      2408 1st Ave   btwn Wall & Battery     47.614406   -122.348155
# 4      2001 4th Ave        at Virginia St     47.613162   -122.340606
#
#                              location.labeledLatLngs  ...  location.country  \
# 0  [{'label': 'display', 'lat': 47.60906474579556...  ...     United States
# 1  [{'label': 'display', 'lat': 47.60883450562949...  ...     United States
# 2  [{'label': 'display', 'lat': 47.60616201806928...  ...     United States
# 3  [{'label': 'display', 'lat': 47.61440633728934...  ...     United States
# 4  [{'label': 'display', 'lat': 47.613162, 'lng':...  ...     United States
#
#                            location.formattedAddress delivery.id  \
# 0  [1514 Pike Pl (in Post Alley), Seattle, WA 98101]     1910007
# 1  [1501 Pike Pl (at Pike Place Market), Seattle,...         NaN
# 2              [1301 Alaskan Way, Seattle, WA 98101]      559475
# 3  [2408 1st Ave (btwn Wall & Battery), Seattle, ...         NaN
# 4  [2001 4th Ave (at Virginia St), Seattle, WA 98...         NaN
#
#                                         delivery.url delivery.provider.name  \
# 0  https://www.grubhub.com/restaurant/three-girls...                grubhub
# 1                                                NaN                    NaN
# 2  https://www.grubhub.com/restaurant/alaskan-sou...                grubhub
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1                                       NaN                          NaN
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#                delivery.provider.icon.name location.neighborhood venuePage.id
# 0  /delivery_provider_grubhub_20180129.png                   NaN          NaN
# 1                                      NaN                   NaN          NaN
# 2  /delivery_provider_grubhub_20180129.png                   NaN          NaN
# 3                                      NaN                   NaN          NaN
# 4                                      NaN              Belltown          NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Filtering the dataframe to show only relevant data

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                        name categories           address  \
# 0        Three Girls Bakery     Bakery      1514 Pike Pl
# 1         Pike Place Bakery     Bakery      1501 Pike Pl
# 2  Alaskan Sourdough Bakery     Bakery  1301 Alaskan Way
# 3            Macrina Bakery     Bakery      2408 1st Ave
# 4             Dahlia Bakery     Bakery      2001 4th Ave
#
#             crossStreet        lat         lng  \
# 0         in Post Alley  47.609065 -122.340913
# 1  at Pike Place Market  47.608835 -122.340498
# 2                   NaN  47.606162 -122.341256
# 3   btwn Wall & Battery  47.614406 -122.348155
# 4        at Virginia St  47.613162 -122.340606
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 47.60906474579556...       229      98101  US
# 1  [{'label': 'display', 'lat': 47.60883450562949...       190      98101  US
# 2  [{'label': 'display', 'lat': 47.60616201806928...       207      98101  US
# 3  [{'label': 'display', 'lat': 47.61440633728934...      1033      98121  US
# 4  [{'label': 'display', 'lat': 47.613162, 'lng':...       653      98121  US
#
#       city state        country  \
# 0  Seattle    WA  United States
# 1  Seattle    WA  United States
# 2  Seattle    WA  United States
# 3  Seattle    WA  United States
# 4  Seattle    WA  United States
#
#                                     formattedAddress neighborhood  \
# 0  [1514 Pike Pl (in Post Alley), Seattle, WA 98101]          NaN
# 1  [1501 Pike Pl (at Pike Place Market), Seattle,...          NaN
# 2              [1301 Alaskan Way, Seattle, WA 98101]          NaN
# 3  [2408 1st Ave (btwn Wall & Battery), Seattle, ...          NaN
# 4  [2001 4th Ave (at Virginia St), Seattle, WA 98...     Belltown
#
#                          id
# 0  47f245d1f964a520974e1fe3
# 1  4b9d10c1f964a5208f8c36e3
# 2  4c77edff93ef236afa74aa0f
# 3  427ff980f964a520d8211fe3
# 4  49fa01c1f964a520a56d1fe3

# %% [markdown]
# ### List all found bakeries within 1,500 meters of Four Seasons Seattle

# %%
dataframe_filtered.name
# Out:
# 0                 Three Girls Bakery
# 1                  Pike Place Bakery
# 2           Alaskan Sourdough Bakery
# 3                     Macrina Bakery
# 4                      Dahlia Bakery
# 5                Sugar Bakery + Cafe
# 6                        Fuji Bakery
# 7           Il Fornaio Bakery & Café
# 8          Specialty’s Café & Bakery
# 9               Seattle Bagel Bakery
# 10              Grand Central Bakery
# 11                 Sun Bakery & Deli
# 12    The Barque Brontes Bakery Café
# 13                  Three Dog Bakery
# 14                            Bakery
# 15               Little Rae's Bakery
# 16                Very French Bakery
# 17                  M's Bakery Piper
# 18                Askatu Bakery Cafe
# 19                   Bullseye Bakery
# 20                post deli & bakery
# 21                Yummy House Bakery
# 22              Little Prague Bakery
# 23                   85C Bakery Cafe
# 24              Wild Rye Cafe Bakery
# 25          Uptown Espresso & Bakery
# 26             Opaline Cafe & Bakery
# 27                 Holy Bee’s Bakery
# 28                         Le Panier
# 29              Seattle Bagel Bakery
# 30                   Standard Bakery
# 31                   Uptown Espresso
# 32                         Le Chatel
# 33           Sisters European Snacks
# 34                      Panera Bread
# Name: name, dtype: object

# %% [markdown]
# ### Visualize the data

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Four Seasons Seattle',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)


venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_f51b802214a1449785dea7cd18d80ceb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f51b802214a1449785dea7cd18d80ceb%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f51b802214a1449785dea7cd18d80ceb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_f51b802214a1449785dea7cd18d80ceb%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B47.607375700000006%2C-122.3391602000244%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# ## Now that I've recognized that there are 34 bakeries nearby Four Seasons Seattle. I will do the same process with Four Seasons Chicago and then compare the two locations.

# %% [markdown]
# ### Define a user-agent to access geocoder for Four Seasons Chicago Hotel

# %%
address = '120 E Delaware Pl, Chicago, IL 60611'

geolocator = Nominatim(user_agent="chicago_foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 41.899607149999994 -87.6248798647693

# %% [markdown]
# ### Define a search query for bakeries near Four Seasons Chicago

# %%
search_query = 'Bakery'
radius = 1500
print(search_query + ' in Chicago .... OK!')
# Out:
# Bakery in Chicago .... OK!

# %% [markdown]
# ### Define Foursquare API URL

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#  Foursquare API URL installed...

# %% [markdown]
# ### Send a GET Request to examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60cffbf29949ca5ee3c9536e'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4b003368f964a520743b22e3',
#     'name': 'Oak Tree Restaurant & Bakery',
#     'location': {'address': '900 N Michigan Ave',
#      'crossStreet': 'at Walton',
#      'lat': 41.89946945812373,
#      'lng': -87.62413145665998,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89946945812373,
#        'lng': -87.62413145665998}],
#      'distance': 63,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['900 N Michigan Ave (at Walton)',
#       'Chicago, IL 60611']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '49f752d2f964a520816c1fe3',
#     'name': 'Corner Bakery Cafe',
#     'location': {'address': '676 N St. Clair',
#      'lat': 41.894285,
#      'lng': -87.623079,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.894285,
#        'lng': -87.623079}],
#      'distance': 610,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['676 N St. Clair', 'Chicago, IL 60611']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '847516',
#      'url': 'https://www.grubhub.com/restaurant/corner-bakery-cafe-676-n-saint-clair-st-chicago/847516?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=847516',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4bca6e0168f976b06b7d5f83',
#     'name': 'Sacred Grounds Bakery & Café',
#     'location': {'address': '845 N Michigan Ave',
#      'crossStreet': 'at Mezzanine Level',
#      'lat': 41.89796390791032,
#      'lng': -87.62304634451678,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89796390791032,
#        'lng': -87.62304634451678}],
#      'distance': 237,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['845 N Michigan Ave (at Mezzanine Level)',
#       'Chicago, IL 60611']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '89488713'},
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '5cb22ae4666116002cd42017',
#     'name': '3 Greens Coffee & Bakery',
#     'location': {'address': '900 N Michigan Ave',
#      'crossStreet': 'E Walton St',
#      'lat': 41.89959,
#      'lng': -87.624855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89959,
#        'lng': -87.624855}],
#      'distance': 2,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['900 N Michigan Ave (E Walton St)',
#       'Chicago, IL 60611']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2560739',
#      'url': 'https://www.grubhub.com/restaurant/3-greens-coffee--bakery-900-michigan-ave-chicago/2560739?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2560739',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4a50c752f964a52023b01fe3',
#     'name': 'Corner Bakery Cafe',
#     'location': {'address': '360 N Michigan Ave, ENTRANCE ON WACKER DRIVE',
#      'crossStreet': 'ENTRANCE ON WACKER DRIVE',
#      'lat': 41.888143471561456,
#      'lng': -87.62512251734734,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.888143471561456,
#        'lng': -87.62512251734734}],
#      'distance': 1276,
#      'postalCode': '60601',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['360 N Michigan Ave, ENTRANCE ON WACKER DRIVE (ENTRANCE ON WACKER DRIVE)',
#       'Chicago, IL 60601']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '847709',
#      'url': 'https://www.grubhub.com/restaurant/corner-bakery-cafe-360-n-michigan-ave-chicago/847709?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=847709',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '51bf06df498e5023f7e1f700',
#     'name': 'West Town Bakery',
#     'location': {'address': '15 E Ohio St',
#      'crossStreet': 'at N State St',
#      'lat': 41.89251830550363,
#      'lng': -87.62746130075247,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89251830550363,
#        'lng': -87.62746130075247}],
#      'distance': 817,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['15 E Ohio St (at N State St)',
#       'Chicago, IL 60611']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '58ab6f1a2980db353bc2dc5b',
#     'name': 'Brown Sugar Bakery',
#     'location': {'address': 'Navy Pier',
#      'lat': 41.89094,
#      'lng': -87.6108,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89094,
#        'lng': -87.6108}],
#      'distance': 1513,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Navy Pier', 'Chicago, IL 60611']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4ac3492df964a5201f9b20e3',
#     'name': 'Corner Bakery Cafe',
#     'location': {'address': '200 N LaSalle St, Ste 100',
#      'crossStreet': 'at Lake St',
#      'lat': 41.885883,
#      'lng': -87.63291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.885883,
#        'lng': -87.63291}],
#      'distance': 1666,
#      'postalCode': '60601',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['200 N LaSalle St, Ste 100 (at Lake St)',
#       'Chicago, IL 60601']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '847658',
#      'url': 'https://www.grubhub.com/restaurant/corner-bakery-200-n-lasalle-st-ste-100-chicago/847658?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=847658',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4e4e52a0bd4101d0d7a7b78d',
#     'name': 'Aigre Doux Restaraunt & Bakery',
#     'location': {'address': '230 W Kinzie St',
#      'lat': 41.88925552368164,
#      'lng': -87.63463592529297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88925552368164,
#        'lng': -87.63463592529297}],
#      'distance': 1407,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['230 W Kinzie St', 'Chicago, IL 60654']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '54997a09498ea7de4fc9fc29',
#     'name': 'Hendricks Bakery',
#     'location': {'lat': 41.899361,
#      'lng': -87.621844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.899361,
#        'lng': -87.621844}],
#      'distance': 253,
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '5bfc6b9fe4c459002c9ed521',
#     'name': '3 Greens Market',
#     'location': {'address': '900 N Michigan Ave',
#      'lat': 41.899644,
#      'lng': -87.624311,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.899644,
#        'lng': -87.624311}],
#      'distance': 47,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['900 N Michigan Ave', 'Chicago, IL 60611']},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4bfff2df92a6c928ab5b43e2',
#     'name': 'Hendrickx Belgian Bread Crafter',
#     'location': {'address': '100 E Walton St',
#      'crossStreet': 'btwn N Rush St & N Lake Shore Dr',
#      'lat': 41.89995565848361,
#      'lng': -87.6252808377943,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89995565848361,
#        'lng': -87.6252808377943}],
#      'distance': 51,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['100 E Walton St (btwn N Rush St & N Lake Shore Dr)',
#       'Chicago, IL 60611']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '349166',
#      'url': 'https://www.grubhub.com/restaurant/hendrickx-belgian-bread-crafter-100-e-walton-st-chicago/349166?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=349166',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '92712021'},
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4f32aba919836c91c7ee5866',
#     'name': 'Jaffa Bakery',
#     'location': {'address': '520 N Michigan Ave',
#      'lat': 41.89156,
#      'lng': -87.624664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89156,
#        'lng': -87.624664}],
#      'distance': 895,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['520 N Michigan Ave', 'Chicago, IL 60611']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '5f1b6bbe27eecc7f8954e213',
#     'name': 'Eva’s Delicious Bakery',
#     'location': {'address': '514 N Peshtigo Ct',
#      'lat': 41.892207,
#      'lng': -87.616637,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.892207,
#        'lng': -87.616637}],
#      'distance': 1070,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['514 N Peshtigo Ct', 'Chicago, IL 60611']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4ed84723722e1da3ffaf3ca1',
#     'name': "Torry's Bakery",
#     'location': {'lat': 41.88723116050467,
#      'lng': -87.6230415241614,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88723116050467,
#        'lng': -87.6230415241614}],
#      'distance': 1386,
#      'postalCode': '60601',
#      'cc': 'US',
#      'state': 'Illinois',
#      'country': 'United States',
#      'formattedAddress': ['IL 60601']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4f3240b919836c91c7c54a41',
#     'name': 'Warburtons Bakery and Cafe',
#     'location': {'address': '233 N Michigan Ave',
#      'lat': 41.887084,
#      'lng': -87.62418000000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.887084,
#        'lng': -87.62418000000001},
#       {'label': 'entrance', 'lat': 41.886898, 'lng': -87.624121}],
#      'distance': 1395,
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['233 N Michigan Ave', 'Chicago, IL']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4b463709f964a520501a26e3',
#     'name': 'Jaffa Bakery',
#     'location': {'address': '201 N Clark St',
#      'crossStreet': 'Lake St.',
#      'lat': 41.886059,
#      'lng': -87.630385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.886059,
#        'lng': -87.630385},
#       {'label': 'entrance', 'lat': 41.885951, 'lng': -87.630848}],
#      'distance': 1575,
#      'postalCode': '60601',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['201 N Clark St (Lake St.)', 'Chicago, IL 60601']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4b058b69f964a52008df22e3',
#     'name': 'Jaffa Bakery',
#     'location': {'address': '225 N Michigan Ave',
#      'crossStreet': 'at Lake St',
#      'lat': 41.88642776320842,
#      'lng': -87.62384169619533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88642776320842,
#        'lng': -87.62384169619533}],
#      'distance': 1469,
#      'postalCode': '60601',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['225 N Michigan Ave (at Lake St)',
#       'Chicago, IL 60601']},
#     'categories': [{'id': '4bf58dd8d48988d179941735',
#       'name': 'Bagel Shop',
#       'pluralName': 'Bagel Shops',
#       'shortName': 'Bagels',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False},
#    {'id': '4a7714bef964a52088e31fe3',
#     'name': 'Au Bon Pain',
#     'location': {'address': '222 Merchandise Mart Plz',
#      'crossStreet': 'at Merchandise Mart',
#      'lat': 41.88830198483088,
#      'lng': -87.63398316603758,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88830198483088,
#        'lng': -87.63398316603758}],
#      'distance': 1467,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['222 Merchandise Mart Plz (at Merchandise Mart)',
#       'Chicago, IL 60654']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1624243186',
#     'hasPerk': False}]}}

# %% [markdown]
# ### Specify my JSON search to bakeries and transforming data into a pandas dataframe

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
#                          id                          name  \
# 0  4b003368f964a520743b22e3  Oak Tree Restaurant & Bakery
# 1  49f752d2f964a520816c1fe3            Corner Bakery Cafe
# 2  4bca6e0168f976b06b7d5f83  Sacred Grounds Bakery & Café
# 3  5cb22ae4666116002cd42017      3 Greens Coffee & Bakery
# 4  4a50c752f964a52023b01fe3            Corner Bakery Cafe
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1624243186    False
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1624243186    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1624243186    False
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1624243186    False
# 4  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1624243186    False
#
#                                location.address      location.crossStreet  \
# 0                            900 N Michigan Ave                 at Walton
# 1                               676 N St. Clair                       NaN
# 2                            845 N Michigan Ave        at Mezzanine Level
# 3                            900 N Michigan Ave               E Walton St
# 4  360 N Michigan Ave, ENTRANCE ON WACKER DRIVE  ENTRANCE ON WACKER DRIVE
#
#    location.lat  location.lng  \
# 0     41.899469    -87.624131
# 1     41.894285    -87.623079
# 2     41.897964    -87.623046
# 3     41.899590    -87.624855
# 4     41.888143    -87.625123
#
#                              location.labeledLatLngs  ...  location.state  \
# 0  [{'label': 'display', 'lat': 41.89946945812373...  ...              IL
# 1  [{'label': 'display', 'lat': 41.894285, 'lng':...  ...              IL
# 2  [{'label': 'display', 'lat': 41.89796390791032...  ...              IL
# 3  [{'label': 'display', 'lat': 41.89959, 'lng': ...  ...              IL
# 4  [{'label': 'display', 'lat': 41.88814347156145...  ...              IL
#
#   location.country                          location.formattedAddress  \
# 0    United States  [900 N Michigan Ave (at Walton), Chicago, IL 6...
# 1    United States               [676 N St. Clair, Chicago, IL 60611]
# 2    United States  [845 N Michigan Ave (at Mezzanine Level), Chic...
# 3    United States  [900 N Michigan Ave (E Walton St), Chicago, IL...
# 4    United States  [360 N Michigan Ave, ENTRANCE ON WACKER DRIVE ...
#
#   delivery.id                                       delivery.url  \
# 0         NaN                                                NaN
# 1      847516  https://www.grubhub.com/restaurant/corner-bake...
# 2         NaN                                                NaN
# 3     2560739  https://www.grubhub.com/restaurant/3-greens-co...
# 4      847709  https://www.grubhub.com/restaurant/corner-bake...
#
#   delivery.provider.name             delivery.provider.icon.prefix  \
# 0                    NaN                                       NaN
# 1                grubhub  https://fastly.4sqi.net/img/general/cap/
# 2                    NaN                                       NaN
# 3                grubhub  https://fastly.4sqi.net/img/general/cap/
# 4                grubhub  https://fastly.4sqi.net/img/general/cap/
#
#   delivery.provider.icon.sizes              delivery.provider.icon.name  \
# 0                          NaN                                      NaN
# 1                     [40, 50]  /delivery_provider_grubhub_20180129.png
# 2                          NaN                                      NaN
# 3                     [40, 50]  /delivery_provider_grubhub_20180129.png
# 4                     [40, 50]  /delivery_provider_grubhub_20180129.png
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2     89488713
# 3          NaN
# 4          NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Filtering the dataframe to show only relevant data

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                            name           categories  \
# 0  Oak Tree Restaurant & Bakery  American Restaurant
# 1            Corner Bakery Cafe               Bakery
# 2  Sacred Grounds Bakery & Café          Coffee Shop
# 3      3 Greens Coffee & Bakery                 Café
# 4            Corner Bakery Cafe               Bakery
#
#                                         address               crossStreet  \
# 0                            900 N Michigan Ave                 at Walton
# 1                               676 N St. Clair                       NaN
# 2                            845 N Michigan Ave        at Mezzanine Level
# 3                            900 N Michigan Ave               E Walton St
# 4  360 N Michigan Ave, ENTRANCE ON WACKER DRIVE  ENTRANCE ON WACKER DRIVE
#
#          lat        lng                                     labeledLatLngs  \
# 0  41.899469 -87.624131  [{'label': 'display', 'lat': 41.89946945812373...
# 1  41.894285 -87.623079  [{'label': 'display', 'lat': 41.894285, 'lng':...
# 2  41.897964 -87.623046  [{'label': 'display', 'lat': 41.89796390791032...
# 3  41.899590 -87.624855  [{'label': 'display', 'lat': 41.89959, 'lng': ...
# 4  41.888143 -87.625123  [{'label': 'display', 'lat': 41.88814347156145...
#
#    distance postalCode  cc     city state        country  \
# 0        63      60611  US  Chicago    IL  United States
# 1       610      60611  US  Chicago    IL  United States
# 2       237      60611  US  Chicago    IL  United States
# 3         2      60611  US  Chicago    IL  United States
# 4      1276      60601  US  Chicago    IL  United States
#
#                                     formattedAddress                        id
# 0  [900 N Michigan Ave (at Walton), Chicago, IL 6...  4b003368f964a520743b22e3
# 1               [676 N St. Clair, Chicago, IL 60611]  49f752d2f964a520816c1fe3
# 2  [845 N Michigan Ave (at Mezzanine Level), Chic...  4bca6e0168f976b06b7d5f83
# 3  [900 N Michigan Ave (E Walton St), Chicago, IL...  5cb22ae4666116002cd42017
# 4  [360 N Michigan Ave, ENTRANCE ON WACKER DRIVE ...  4a50c752f964a52023b01fe3

# %% [markdown]
# ### List all found bakeries near Four Seasons Chicago

# %%
dataframe_filtered.name
# Out:
# 0        Oak Tree Restaurant & Bakery
# 1                  Corner Bakery Cafe
# 2        Sacred Grounds Bakery & Café
# 3            3 Greens Coffee & Bakery
# 4                  Corner Bakery Cafe
# 5                    West Town Bakery
# 6                  Brown Sugar Bakery
# 7                  Corner Bakery Cafe
# 8      Aigre Doux Restaraunt & Bakery
# 9                    Hendricks Bakery
# 10                    3 Greens Market
# 11    Hendrickx Belgian Bread Crafter
# 12                       Jaffa Bakery
# 13             Eva’s Delicious Bakery
# 14                     Torry's Bakery
# 15         Warburtons Bakery and Cafe
# 16                       Jaffa Bakery
# 17                       Jaffa Bakery
# 18                        Au Bon Pain
# Name: name, dtype: object

# %% [markdown]
# ### Visualize the data

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Four Seasons Chicago',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)


venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_0f3534d7aa1345f9adfe22882c504493%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0f3534d7aa1345f9adfe22882c504493%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0f3534d7aa1345f9adfe22882c504493%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_0f3534d7aa1345f9adfe22882c504493%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B41.899607149999994%2C-87.6248798647693%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20 ...

# %% [markdown]
# # Overview:
#
# ## Problem: Between the two locations, which city has the most bakeries nearby their respected Four Seasons Hotel?
#
#
# #### Seattle, Washington has a total of: 34 bakeries
# #### Chicago, Illinois has a total of: 19 bakeries
